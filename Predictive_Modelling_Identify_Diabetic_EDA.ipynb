# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px
import plotly as plt
import matplotlib.pyplot as plt

# %%
# !pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\aruni\anaconda3\lib\site-packages (5.22.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\aruni\anaconda3\lib\site-packages (from plotly) (8.2.2)
# Requirement already satisfied: packaging in c:\users\aruni\anaconda3\lib\site-packages (from plotly) (23.2)

# %%
df_final = pd.read_csv('C:\\Sample_Data\\final.csv', index_col = [0])

# %%
df_final
# Out:
#        SEQN  Cadmium (ug/L)  Lead (ug/dL)  Blood manganese (ug/L)  \
# 0     73559            0.22          1.45                    9.57
# 1     73564            0.37          1.00                   16.80
# 3     73607            0.50          1.35                    8.31
# 4     73621            0.36          1.38                    8.14
# 5     73633            0.07          0.59                    9.62
# ...     ...             ...           ...                     ...
# 9886  83717            0.79          1.62                   11.19
# 9888  83721            0.79          1.62                   11.19
# 9889  83724            0.79          1.62                   11.19
# 9890  83726            0.79          1.62                   11.19
# 9891  83728            0.79          1.62                   11.19
#
#       Mercury, total (ug/L)  Blood selenium(ug/L)  LDL-Cholesterol  \
# 0                      1.27                209.64           126.00
# 1                      0.42                195.62           168.00
# 3                      0.33                219.00           161.00
# 4                      0.87                212.84           161.00
# 5                      0.20                168.49           195.00
# ...                     ...                   ...              ...
# 9886                   2.41                205.41           222.35
# 9888                   2.41                205.41           222.35
# 9889                   2.41                205.41           222.35
# 9890                   2.41                205.41           222.35
# 9891                   2.41                205.41           222.35
#
#       Lymphocyte number  Monocyte number  Segmented neutrophils number  ...  \
# 0                   1.0             0.80                          4.90  ...
# 1                   1.6             0.30                          3.00  ...
# 3                   2.3             0.60                          3.80  ...
# 4                   0.8             0.40                          2.80  ...
# 5                   2.1             0.50                          5.00  ...
# ...                 ...              ...                           ...  ...
# 9886                2.2             0.54                          3.93  ...
# 9888                2.2             0.54                          3.93  ...
# 9889                2.2             0.54                          3.93  ...
# 9890                2.2             0.54                          3.93  ...
# 9891                2.2             0.54                          3.93  ...
#
#       Citizenship             USStayLength       MaritalStatus  \
# 0               1                  Unknown             Married
# 1               1                  Unknown  Separated/Divorced
# 3               1                  Unknown             Married
# 4               1                  Unknown             Married
# 5               1                  Unknown             Married
# ...           ...                      ...                 ...
# 9886            0   Long Term (> 10 Years)  Separated/Divorced
# 9888            1  Short Term (< 10 Years)             Married
# 9889            1                  Unknown             Married
# 9890            0   Long Term (> 10 Years)  Separated/Divorced
# 9891            1                  Unknown             Unknown
#
#       PregnancyStatus  FamilyIncome  PovertyRatio  is_diabetic  large_family  \
# 0       NotApplicable        Medium          4.51            1           0.0
# 1             Unknown        Medium          5.00            0           0.0
# 3       NotApplicable           Low          1.08            0           0.0
# 4       NotApplicable        Medium          5.00            1           0.0
# 5         NotPregnant        Medium          3.56            0           1.0
# ...               ...           ...           ...          ...           ...
# 9886          Unknown           Low          0.70            0           1.0
# 9888    NotApplicable          High          5.00            0           0.0
# 9889    NotApplicable           Low          3.09            0           0.0
# 9890    NotApplicable        Medium          3.81            0           0.0
# 9891          Unknown           Low          1.95            0           1.0
#
#       college_educated  high_risk
# 0                  1.0          1
# 1                  1.0          0
# 3                  0.0          0
# 4                  1.0          0
# 5                  1.0          0
# ...                ...        ...
# 9886               0.0          0
# 9888               1.0          1
# 9889               0.0          0
# 9890               0.0          1
# 9891               2.0          0
#
# [8971 rows x 83 columns]

# %%
df_final.dropna(inplace = True)

# %%
df_final
# Out:
#        SEQN  Cadmium (ug/L)  Lead (ug/dL)  Blood manganese (ug/L)  \
# 0     73559            0.22          1.45                    9.57
# 1     73564            0.37          1.00                   16.80
# 3     73607            0.50          1.35                    8.31
# 4     73621            0.36          1.38                    8.14
# 5     73633            0.07          0.59                    9.62
# ...     ...             ...           ...                     ...
# 9886  83717            0.79          1.62                   11.19
# 9888  83721            0.79          1.62                   11.19
# 9889  83724            0.79          1.62                   11.19
# 9890  83726            0.79          1.62                   11.19
# 9891  83728            0.79          1.62                   11.19
#
#       Mercury, total (ug/L)  Blood selenium(ug/L)  LDL-Cholesterol  \
# 0                      1.27                209.64           126.00
# 1                      0.42                195.62           168.00
# 3                      0.33                219.00           161.00
# 4                      0.87                212.84           161.00
# 5                      0.20                168.49           195.00
# ...                     ...                   ...              ...
# 9886                   2.41                205.41           222.35
# 9888                   2.41                205.41           222.35
# 9889                   2.41                205.41           222.35
# 9890                   2.41                205.41           222.35
# 9891                   2.41                205.41           222.35
#
#       Lymphocyte number  Monocyte number  Segmented neutrophils number  ...  \
# 0                   1.0             0.80                          4.90  ...
# 1                   1.6             0.30                          3.00  ...
# 3                   2.3             0.60                          3.80  ...
# 4                   0.8             0.40                          2.80  ...
# 5                   2.1             0.50                          5.00  ...
# ...                 ...              ...                           ...  ...
# 9886                2.2             0.54                          3.93  ...
# 9888                2.2             0.54                          3.93  ...
# 9889                2.2             0.54                          3.93  ...
# 9890                2.2             0.54                          3.93  ...
# 9891                2.2             0.54                          3.93  ...
#
#       Citizenship             USStayLength       MaritalStatus  \
# 0               1                  Unknown             Married
# 1               1                  Unknown  Separated/Divorced
# 3               1                  Unknown             Married
# 4               1                  Unknown             Married
# 5               1                  Unknown             Married
# ...           ...                      ...                 ...
# 9886            0   Long Term (> 10 Years)  Separated/Divorced
# 9888            1  Short Term (< 10 Years)             Married
# 9889            1                  Unknown             Married
# 9890            0   Long Term (> 10 Years)  Separated/Divorced
# 9891            1                  Unknown             Unknown
#
#       PregnancyStatus  FamilyIncome  PovertyRatio  is_diabetic  large_family  \
# 0       NotApplicable        Medium          4.51            1           0.0
# 1             Unknown        Medium          5.00            0           0.0
# 3       NotApplicable           Low          1.08            0           0.0
# 4       NotApplicable        Medium          5.00            1           0.0
# 5         NotPregnant        Medium          3.56            0           1.0
# ...               ...           ...           ...          ...           ...
# 9886          Unknown           Low          0.70            0           1.0
# 9888    NotApplicable          High          5.00            0           0.0
# 9889    NotApplicable           Low          3.09            0           0.0
# 9890    NotApplicable        Medium          3.81            0           0.0
# 9891          Unknown           Low          1.95            0           1.0
#
#       college_educated  high_risk
# 0                  1.0          1
# 1                  1.0          0
# 3                  0.0          0
# 4                  1.0          0
# 5                  1.0          0
# ...                ...        ...
# 9886               0.0          0
# 9888               1.0          1
# 9889               0.0          0
# 9890               0.0          1
# 9891               2.0          0
#
# [8971 rows x 83 columns]

# %%
df_final.loc[df_final['Body Mass Index (kg/m**2)'] >30, 'bmi_group'] = 'Obese'

# %%
df_final.loc[df_final['Body Mass Index (kg/m**2)'] < 30 , 'bmi_group'] = 'Overweight'

# %%
df_final.loc[df_final['Body Mass Index (kg/m**2)'] < 25 , 'bmi_group'] = 'Healthy'

# %%
df_final.loc[df_final['Body Mass Index (kg/m**2)'] <= 18.5 , 'bmi_group'] = 'Underweight'

# %%
print(df_final.loc[df_final['bmi_group'] == 'Obese'].shape[0]/8971*100)
# Out:
# 30.97759447107346

# %%
print(df_final.loc[df_final['bmi_group'] == 'Obese'].shape[0]/8971* 100)
# Out:
# 30.97759447107346

# %%
print(df_final.loc[df_final['bmi_group'] == 'Overweight'].shape[0]/8971*100)
# Out:
# 29.874038568721435

# %%
print(df_final.shape)
# Out:
# (8971, 84)

# %%
df = df.rename(columns={'DiabetesPrecictionPDF' : 'PDF'})

# %%
# Replacing the 0 values from ['Glucose','BloodPressure','SkinThickness','Insulin','BMI'] by NaN
df_copy = df.copy(deep=True)

# %%
df_copy.dropna()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df_copy = df.copy(deep=True)

# %%
# Out:
# Total Rows 244

# %%
print(f'Total Rows {df_copy.shape[0]}')
# Out:
# Total Rows 244

# %%
print(f'Total Rows {df_copy.shape[1]}')
# Out:
# Total Rows 7

# %%
####Data Visualization
#Collect all columns having Missing values and at what percentage
columns_with_na=[features for features in df_copy.columns if df_copy[features].isnull().sum()>0]
for feature in columns_with_na:
    print(feature, np.round(df_copy[feature].isnull().mean(), 4),  ' % missing values')

# %%
s1 = df_final[df_final['is_diabetic'] == 1].sample(896).index
s0 = df_final[df_final['is_diabetic'] == 0].sample(1796).index

# %%
df = df_final.loc[s0.union(s1)]

# %%
print('True Negative: {}'.format(df[(df['high_risk'] == 0) & (df['is_diabetic'] == 0)].shape[0]))

#True Positive
print('True Positive: {}'.format(df[(df['high_risk'] == 1) & (df['is_diabetic'] == 1)].shape[0]))

#False Negative
print('False Negative: {}'.format(df[(df['high_risk'] == 0) & (df['is_diabetic'] == 1)].shape[0]))

#False Positive
print('False Positive: {}'.format(df[(df['high_risk'] == 1) & (df['is_diabetic'] == 0)].shape[0]))
# Out:
# True Negative: 1666
# True Positive: 182
# False Negative: 714
# False Positive: 130
